# %%
# !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 207 kB 13.7 MB/s
# ...
#      |████████████████████████████████| 145 kB 67.9 MB/s
# ...
#      |████████████████████████████████| 26.9 MB 1.3 MB/s
# ...

# %%
import os

# %%
import PIL
import os
import os.path
from PIL import Image


path = r'/content/drive/MyDrive/DatasetStylegan'
print(os.listdir(path))
# Out:
# ['Madhuri', 'SRK', 'kajol', 'Akshay', 'Anupamkher', 'RishiKapoor', 'Aamir', 'Jayabhaudhuri', 'Vinod', 'NTR']

# %%
  for file in os.listdir(path): 
      f_img = path+"/"+file
      print(f_img)
      for file2 in os.listdir(f_img):
           k_img=f_img+'/'+file2
           img = Image.open(k_img)
           img = img.resize((256, 256)) #(width, height)
           img.save(k_img)
# Out:
# /content/drive/MyDrive/DatasetStylegan/Madhuri
# /content/drive/MyDrive/DatasetStylegan/SRK
# /content/drive/MyDrive/DatasetStylegan/kajol
# /content/drive/MyDrive/DatasetStylegan/Akshay
# /content/drive/MyDrive/DatasetStylegan/Anupamkher
# /content/drive/MyDrive/DatasetStylegan/RishiKapoor
# /content/drive/MyDrive/DatasetStylegan/Aamir
# /content/drive/MyDrive/DatasetStylegan/Jayabhaudhuri
# /content/drive/MyDrive/DatasetStylegan/Vinod
# /content/drive/MyDrive/DatasetStylegan/NTR

# %%
img2=cv2.imread('/content/drive/MyDrive/DatasetStylegan/Jayabhaudhuri/JayaBhaduri_100.jpg')
img2.shape
# Out:
# (250, 250, 3)

# %%
resized_imgs
# Out:
# array([], dtype=float64)

# %%
import cv2

# %%
# !git clone https://github.com/rkuo2000/stylegan2-ada-pytorch
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 151, done.
# remote: Total 151 (delta 0), reused 0 (delta 0), pack-reused 151
# Receiving objects: 100% (151/151), 1.13 MiB | 2.32 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
# %cd stylegan2-ada-pytorch
# Out:
# /content/stylegan2-ada-pytorch

# %%
# !python train.py --outdir '/content/drive/MyDrive/Result'  --data '/content/drive/MyDrive/stylegan3-t-afhqv2-512x512.zip' --batch 2 --gpus 1
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/stylegan3-t-afhqv2-512x512.zip",
#     "use_labels": false,
#     "max_size": 127,
#     "xflip": false,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 207, done.
# remote: Total 207 (delta 0), reused 0 (delta 0), pack-reused 207
# Receiving objects: 100% (207/207), 4.17 MiB | 10.10 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
# %cd stylegan3
# Out:
# /content/stylegan3

# %%
# !python train.py --outdir='/content/drive/MyDrive/Result'-runs --cfg=stylegan2 --data='/content/drive/MyDrive/stylegan3-t-afhqv2-512x512.zip'  --gpus=1 --batch=4 --gamma=8.8 --mirror=1 --aug=noaug
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan2.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "fused_modconv_default": "inference_only"
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
# ...
